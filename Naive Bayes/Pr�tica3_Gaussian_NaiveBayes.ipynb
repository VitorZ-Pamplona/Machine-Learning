# %% [markdown]
# <font color="darkblue"> Prática 03: Gaussian Naive Bayes </font>

# %% [markdown]
# **Objetivos:**
#
# *   Executar o algortimo *GaussianNaiveBayes* e analisar seu desempenho sobre dados para classificação de lírios (distribuição gaussiana).

# %% [markdown]
# **Atividade 1:**
#
# 1. Dados sobre 3 tipos de lírios (flores) para serem classificados, disponível em:  https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris
# 2. Carregar os dados usando a função *load_iris* do pacote  *sklearn.datasets*.

# %%
# load the iris dataset 
from sklearn.datasets import load_iris

iris = load_iris()

# %% [markdown]
# **Atividade 2:**
#
# 1. Plotar as 2 primeiras características dos dados em um grafico de disprsão, exibindo cores distints para cada tipo de flor.

# %%
import matplotlib.pyplot as plt

X = iris.data
y = iris.target

plt.figure(2, figsize=(8,6))

plt.scatter(X[:, 0], X[:,1], c=y)

plt.xlabel('Sepal length')
plt.ylabel('Sepal wigth')
# Out:
# Text(0, 0.5, 'Sepal wigth')

# %% [markdown]
# **Atividade 3:**
#
# 1. Dividir entrada em dados de treino e teste.

# %%
# splitting X and y into training and testing sets 
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1)

# %% [markdown]
# **Atividade 4:**
# 1. Utilizar a classe *GaussianNB* do pacote *sklearn.naive_bayes* para ajustar com os dados de treino;
# 2. Usar os dados de teste para computar as probabilidades e suas predições de classificação;
# 3. Computar as métricas de aprendizado com os dados de teste.

# %%
from sklearn.naive_bayes import GaussianNB 

gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_prob = gnb.predict_proba(X_test)
#print(y_prob)

y_pred = gnb.predict(X_test)
print(y_pred)
# Out:
# [0 1 1 0 2 2 2 0 0 2 1 0 2 1 1 0 1 1 0 0 1 1 2 0 2 1 0 0 1 2 1 2 1 2 2 0 1
#  0 1 2 2 0 1 2 1 2 0 0 0 1 0 0 2 2 2 2 2 1 2 1]

# %% [markdown]
# **Atividade 5:**
#
# 1. Plotar num grafico de barras as palavras que mais aparecem como *spam* e não *spam*.

# %%
from sklearn.metrics import classification_report, accuracy_score

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.95      0.90      0.93        21
#            2       0.90      0.95      0.93        20
#
#     accuracy                           0.95        60
#    macro avg       0.95      0.95      0.95        60
# weighted avg       0.95      0.95      0.95        60
